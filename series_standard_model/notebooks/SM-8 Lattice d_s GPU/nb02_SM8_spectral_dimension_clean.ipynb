# %% [markdown]
# # Spectral Dimension Extraction for SM8 Cage Graph
# This notebook loads the GPU‑generated return‑probability CSV and fits
# \[
# P(t) \sim t^{-d_s/2}
# \]
# to extract the spectral dimension \( d_s \).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("nb02_SM8_600cell_2ring_return_prob.csv")

t_vals = df["t"].values
P_t = df["P"].values

print("Loaded", len(t_vals), "time steps")

# %%
df.columns

# %%
plt.figure(figsize=(6,4))
plt.loglog(t_vals[1:], P_t[1:], 'o-', markersize=3)
plt.xlabel("t")
plt.ylabel("P(t)")
plt.title("Return probability (log-log)")
plt.grid(True, which="both", ls="--", alpha=0.3)
plt.show()

# %%
t_min, t_max = 50, 500
print("Scaling window:", t_min, "to", t_max)

# %%
mask = (df["t"] >= t_min) & (df["t"] <= t_max)
print("Number of points in window:", mask.sum())

# %%
x = np.log(df["t"][mask])
y = np.log(df["P"][mask])

print("log(t) range:", x.min(), "to", x.max())
print("log(P) range:", y.min(), "to", y.max())

# %%
slope, intercept = np.polyfit(x, y, 1)
d_s = -2 * slope

print("Slope:", slope)
print("Spectral dimension d_s:", d_s)

# %%
x_fit = ...
y_fit = ...

# %%
plt.figure(figsize=(6,4))
plt.loglog(df["t"], df["P"], 'o', markersize=2, label="data")

x_fit = np.linspace(np.log(t_min), np.log(t_max), 200)
y_fit = slope * x_fit + intercept
plt.loglog(np.exp(x_fit), np.exp(y_fit), 'r-', label="fit")

plt.xlabel("t")
plt.ylabel("P(t)")
plt.legend()
plt.title("Spectral Dimension Fit")
plt.show()

# %%
PROJECT_ROOT = Path(".").resolve()

# 2‑ring edge list
EDGE_LIST_PATH = PROJECT_ROOT / "nb02_SM8_tiled600cell_2ring_edgelist.txt"

# Output CSV
OUTPUT_CSV_PATH = PROJECT_ROOT / "nb02_SM8_600cell_2ring_return_prob.csv"

print("Edge list path:", EDGE_LIST_PATH)
print("Output CSV path:", OUTPUT_CSV_PATH)

def load_edge_list(path: Path):
    edges = []
    with path.open("r") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#"):
                continue
            parts = line.split()
            if len(parts) != 2:
                raise ValueError(f"Bad edge line: {line}")
            u, v = map(int, parts)
            edges.append((u, v))
    return np.array(edges, dtype=np.int64)

edges = load_edge_list(EDGE_LIST_PATH)
print("Loaded edges:", edges.shape)

min_vertex = edges.min()
if min_vertex != 0:
    print(f"Normalizing vertices by subtracting {min_vertex}")
    edges = edges - min_vertex

num_vertices = int(edges.max()) + 1
print("Number of vertices:", num_vertices)

# %%
slope, intercept = np.polyfit(x, y, 1)
d_s = -2 * slope

print("Slope:", slope)
print("Spectral dimension d_s:", d_s)

# %%
plt.figure(figsize=(6,4))
plt.loglog(df["t"], df["P"], 'o', markersize=2, label="data")

x_fit = np.linspace(np.log(t_min), np.log(t_max), 200)
y_fit = slope * x_fit + intercept
plt.loglog(np.exp(x_fit), np.exp(y_fit), 'r-', label="fit")

plt.xlabel("t")
plt.ylabel("P(t)")
plt.legend()
plt.title("Spectral Dimension Fit")
plt.show()

# %%
mask = (t_vals >= t_min) & (t_vals <= t_max)

log_t = np.log(t_vals[mask])
log_P = np.log(P_t[mask])

print("Points in window:", len(log_t))

# %%
slope, intercept = np.polyfit(log_t, log_P, 1)
d_s = -2 * slope

print(f"Slope m = {slope:.6f}")
print(f"Spectral dimension d_s = {d_s:.6f}")

# %%
plt.figure(figsize=(5,4))
plt.plot(log_t, log_P, "o", markersize=3, label="data")
plt.plot(log_t, slope*log_t + intercept, "r-", label=f"fit (d_s={d_s:.3f})")
plt.xlabel("log t")
plt.ylabel("log P(t)")
plt.legend()
plt.title(f"Fit on t ∈ [{t_min}, {t_max}]")
plt.grid(True, ls="--", alpha=0.3)
plt.show()

# %%
# Save a copy of the return-probability data into the project notebooks folder
output_path = "nb02_SM8_return_prob_data_current_graph_copy.csv"
df.to_csv(output_path, index=False)
print("Saved CSV to:", output_path)

# %%
Spectral dimension d_s:

# %%
import json
import sys
print(sys.argv)
# Out:
# ['C:\\Users\\DrThomas\\anaconda3\\envs\\cpp311\\Lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\DrThomas\\AppData\\Roaming\\jupyter\\runtime\\kernel-5bb4f7e1-9fba-4ca0-86a8-d5afe10c7ed6.json']

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3      C:\Users\DrThomas\anaconda3\envs\cpp311\share\jupyter\kernels\python3
#   cpp311       C:\Users\DrThomas\AppData\Roaming\jupyter\kernels\cpp311
#   torch_env    C:\Users\DrThomas\AppData\Roaming\jupyter\kernels\torch_env
